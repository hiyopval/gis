# %% [markdown]
# #  都内でおすすめのカフェ5選

# %%
# import folium, a leaflet python library
import folium

# create a list of lat/lon pair for UCLA
JonesCafeBar = [35.685689958293516, 139.69210725235016]
jaho = [35.646256019537944, 139.74503494807047]
NINAS = [35.67431000616222, 139.7600507693085]
Buvette = [35.67391352619888, 139.75919765420448]
accueil = [35.651040103534676, 139.7069992233782]
nogizaka = [35.666961675658605, 139.72650782519426]


# make the map
m = folium.Map(location=nogizaka, zoom_start=12)

# add a marker
folium.Marker(JonesCafeBar, popup="The Jones Cafe Bar, the best place on earth!", tooltip="The Jones Cafe Bar").add_to(m)
folium.Marker(jaho, popup="Jahocoffeejapan, the best place on earth!", tooltip="Jahocoffeejapan").add_to(m)
folium.Marker(NINAS, popup="LE SALON DE NINA'S, the best place on earth!", tooltip="LE SALON DE NINA'S").add_to(m)
folium.Marker(Buvette, popup="Buvette Tokyo, the best place on earth!", tooltip="Buvette Tokyo").add_to(m)
folium.Marker(accueil, popup="cafe accueil, the best place on earth!", tooltip="cafe accueil").add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5f095f056e9a84dd637c1879208861a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5f095f056e9a84dd637c1879208861a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5f095f056e9a84dd637c1879208861a = L.map(
#                 &quot;map_b5f095f056e9a84dd637c1879208861a&quot;,
#                 {
#                     center: [35.666961675658605, 139.72650782519426],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e93ba02128d82b9b0ba24a34a2dced7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7e93ba02128d82b9b0ba24a34a2dced7.addTo(map_b5f095f056e9a84dd637c1879208861a);
#
#
#             var marker_96f010aec51abf06130ae14a6992155e = L.marker(
#                 [35.685689958293516, 139.69210725235016],
#                 {}
#             ).addTo(map_b5f095f056e9a84dd637c1879208861a);
#
#
#         var popup_98f536b334e6c4ceef7edc877c94aedc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22a203abee298c86c915b5f70c2804ae = $(`&lt;div id=&quot;html_22a203abee298c86c915b5f70c2804ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Jones Cafe Bar, the best place on earth!&lt;/div&gt;`)[0];
#                 popup_98f536b334e6c4ceef7edc877c94aedc.setContent(html_22a203abee298c86c915b5f70c2804ae);
#
#
#
#         marker_96f010aec51abf06130ae14a6992155e.bindPopup(popup_98f536b334e6c4ceef7edc877c94aedc)
#         ;
#
#
#
#
#             marker_96f010aec51abf06130ae14a6992155e.bindTooltip(
#                 `&lt;div&gt;
#                      The Jones Cafe Bar
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3447b227e65b837cc3bb8fd85add2c3d = L.marker(
#                 [35.646256019537944, 139.74503494807047],
#                 {}
#             ).addTo(map_b5f095f056e9a84dd637c1879208861a);
#
#
#         var popup_2f0e872d5164de14e5ddab79cc3005e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ca5b8ef917aabaf43afbb8ac2ae3f80 = $(`&lt;div id=&quot;html_1ca5b8ef917aabaf43afbb8ac2ae3f80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jahocoffeejapan, the best place on earth!&lt;/div&gt;`)[0];
#                 popup_2f0e872d5164de14e5ddab79cc3005e9.setContent(html_1ca5b8ef917aabaf43afbb8ac2ae3f80);
#
#
#
#         marker_3447b227e65b837cc3bb8fd85add2c3d.bindPopup(popup_2f0e872d5164de14e5ddab79cc3005e9)
#         ;
#
#
#
#
#             marker_3447b227e65b837cc3bb8fd85add2c3d.bindTooltip(
#                 `&lt;div&gt;
#                      Jahocoffeejapan
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_975c909204edf257add0c30aeb22585b = L.marker(
#                 [35.67431000616222, 139.7600507693085],
#                 {}
#             ).addTo(map_b5f095f056e9a84dd637c1879208861a);
#
#
#         var popup_7c1378e462f4b3a045d87d4237f3e7dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d86d69c6b6d7e7f5c7a43168a46e539 = $(`&lt;div id=&quot;html_6d86d69c6b6d7e7f5c7a43168a46e539&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LE SALON DE NINA&#x27;S, the best place on earth!&lt;/div&gt;`)[0];
#                 popup_7c1378e462f4b3a045d87d4237f3e7dc.setContent(html_6d86d69c6b6d7e7f5c7a43168a46e539);
#
#
#
#         marker_975c909204edf257add0c30aeb22585b.bindPopup(popup_7c1378e462f4b3a045d87d4237f3e7dc)
#         ;
#
#
#
#
#             marker_975c909204edf257add0c30aeb22585b.bindTooltip(
#                 `&lt;div&gt;
#                      LE SALON DE NINA&#x27;S
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_14b843b89037f92f3410ff19ad2e9786 = L.marker(
#                 [35.67391352619888, 139.75919765420448],
#                 {}
#             ).addTo(map_b5f095f056e9a84dd637c1879208861a);
#
#
#         var popup_d40870e875780e8a3291dfcc7e455080 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35c23527a7d97655f5aa51d6eca15a14 = $(`&lt;div id=&quot;html_35c23527a7d97655f5aa51d6eca15a14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buvette Tokyo, the best place on earth!&lt;/div&gt;`)[0];
#                 popup_d40870e875780e8a3291dfcc7e455080.setContent(html_35c23527a7d97655f5aa51d6eca15a14);
#
#
#
#         marker_14b843b89037f92f3410ff19ad2e9786.bindPopup(popup_d40870e875780e8a3291dfcc7e455080)
#         ;
#
#
#
#
#             marker_14b843b89037f92f3410ff19ad2e9786.bindTool

# %%
# 地図保存
m.save('Tokyo_cafe.html')
