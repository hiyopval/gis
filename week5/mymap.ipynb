# %% [markdown]
# #  都内で行ったことがあるカフェ5選

# %%
# import folium, a leaflet python library
import folium

# create a list of lat/lon pair for UCLA
JonesCafeBar = [35.685689958293516, 139.69210725235016]
jaho = [35.646256019537944, 139.74503494807047]
NINAS = [35.67431000616222, 139.7600507693085]
Buvette = [35.67391352619888, 139.75919765420448]
accueil = [35.651040103534676, 139.7069992233782]
nogizaka = [35.666961675658605, 139.72650782519426]


# make the map
m = folium.Map(location=nogizaka, zoom_start=12)

# add a marker
folium.Marker(
    JonesCafeBar, 
    popup="The Jones Cafe Bar, いいお値段だったよ！", 
    tooltip="The Jones Cafe Bar",
    icon=folium.Icon(color="lightblue", icon="cutlery")
).add_to(m)

folium.Marker(
    jaho, 
    popup="Jahocoffeejapan, 会社説明会の帰りに行ったよ！", 
    tooltip="Jahocoffeejapan",
    icon=folium.Icon(color="pink", icon="cutlery")
).add_to(m)

folium.Marker(
    NINAS, 
    popup="LE SALON DE NINA'S, 母親と行ったよ！", 
    tooltip="LE SALON DE NINA'S",
    icon=folium.Icon(color="beige", icon="cutlery")
).add_to(m)

folium.Marker(
    Buvette, 
    popup="Buvette Tokyo, 高校の友達といったよ！", 
    tooltip="Buvette Tokyo",
    icon=folium.Icon(color="purple", icon="cutlery")
).add_to(m)

folium.Marker(
    accueil, 
    popup="cafe accueil, 高校の友達といったよ！", 
    tooltip="cafe accueil",
    icon=folium.Icon(color="red", icon="cutlery")
).add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d4b74fc178b182ded72624258cb831f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d4b74fc178b182ded72624258cb831f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d4b74fc178b182ded72624258cb831f = L.map(
#                 &quot;map_3d4b74fc178b182ded72624258cb831f&quot;,
#                 {
#                     center: [35.666961675658605, 139.72650782519426],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a6ca5cbf54302ca092f52ba9d013578 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5a6ca5cbf54302ca092f52ba9d013578.addTo(map_3d4b74fc178b182ded72624258cb831f);
#
#
#             var marker_1728dcbc4380d3caaaa5b657b28b4049 = L.marker(
#                 [35.685689958293516, 139.69210725235016],
#                 {}
#             ).addTo(map_3d4b74fc178b182ded72624258cb831f);
#
#
#             var icon_a98cb2e1e1dc520b7913c4e76750fbd0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1728dcbc4380d3caaaa5b657b28b4049.setIcon(icon_a98cb2e1e1dc520b7913c4e76750fbd0);
#
#
#         var popup_611e68744d3ba7083db94779f0e24b3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a861a425668a6faef7b782602aba97e = $(`&lt;div id=&quot;html_9a861a425668a6faef7b782602aba97e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Jones Cafe Bar, いいお値段だったよ！&lt;/div&gt;`)[0];
#                 popup_611e68744d3ba7083db94779f0e24b3e.setContent(html_9a861a425668a6faef7b782602aba97e);
#
#
#
#         marker_1728dcbc4380d3caaaa5b657b28b4049.bindPopup(popup_611e68744d3ba7083db94779f0e24b3e)
#         ;
#
#
#
#
#             marker_1728dcbc4380d3caaaa5b657b28b4049.bindTooltip(
#                 `&lt;div&gt;
#                      The Jones Cafe Bar
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_25ad5485d5a91b9c2e428cb03472d8fa = L.marker(
#                 [35.646256019537944, 139.74503494807047],
#                 {}
#             ).addTo(map_3d4b74fc178b182ded72624258cb831f);
#
#
#             var icon_03f5e60f5c69c03e7bf5edb79a5d483a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_25ad5485d5a91b9c2e428cb03472d8fa.setIcon(icon_03f5e60f5c69c03e7bf5edb79a5d483a);
#
#
#         var popup_2ddf70c03f280c8baf7f94a06865e7d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_488bcdabb153dfcad4e41d24b6ea5679 = $(`&lt;div id=&quot;html_488bcdabb153dfcad4e41d24b6ea5679&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jahocoffeejapan, 会社説明会の帰りに行ったよ！&lt;/div&gt;`)[0];
#                 popup_2ddf70c03f280c8baf7f94a06865e7d8.setContent(html_488bcdabb153dfcad4e41d24b6ea5679);
#
#
#
#         marker_25ad5485d5a91b9c2e428cb03472d8fa.bindPopup(popup_2ddf70c03f280c8baf7f94a06865e7d8)
#         ;
#
#
#
#
#             marker_25ad5485d5a91b9c2e428cb03472d8fa.bindTooltip(
#                 `&lt;div&gt;
#                      Jahocoffeejapan
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_960927d71d473d884f4ab76ed04d70e8 = L.marker(
#                 [35.67431000616222, 139.7600507693085],
#                 {}
#             ).addTo(map_3d4b74fc178b182ded72624258cb831f);
#
#
#             var icon_1b9668f1fc55c0f0a53038b57c5045cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_960927d71d473d884f4ab76ed04d70e8.setIcon(icon_1b9668f1fc55c0f0a53038b57c5045cc);
#
#
#         var popup_a6be97112fe1781be846d012f1dee98c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d2c4adf856116144aa1e708f472528e = $(`&lt;div id=&quot;html_9d2c4adf856116144aa1e708f472528e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LE SALON DE NINA&#x27;S, 母親と行ったよ！&lt;/div&gt;`)[0];
#                 popup_a6be97112fe1781be846d012f1dee98c.setContent(html_9d2c4adf856116144aa1e708f4725

# %%
m.save('Tokyo_cafe.html')
